# %% [markdown]
# <a href="https://colab.research.google.com/github/alifele/Machine_learning/blob/master/Little_functions%26Little_Tricks/roaming_GitHub.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/alifele/Neuro_Science.git
# Out:
# Cloning into 'Neuro_Science'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 45 (delta 15), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (45/45), done.

# %%
# %cd
# Out:
# /root

# %%
# !ls
# Out:
# Neuro_Science

# %%
# %ls
# Out:
# Neuro_Science/

# %%
# %cd Neuro_Science
# %ls
# Out:
# /root/Neuro_Science
# Data.npy                Neuro_PCA.ipynb
# DataSet_with_Label.npz  README.md
# IF_data.npz             Techniques_with_Bias_and_Variance.ipynb

# %%
import numpy as np
data =  np.load('Data.npy')

# %% [markdown]
# #An other import
# I am going to import 'cat-dog' data set from Kaggle.
# someone (thanks to him!) had upladed the data on github and i am going to import the data with cloneing his repository and then navigating to the floder containing the data

# %%
# !git clone https://github.com/ardamavi/Dog-Cat-Classifier.git
# Out:
# Cloning into 'Dog-Cat-Classifier'...
# remote: Enumerating objects: 1654, done.
# remote: Total 1654 (delta 0), reused 0 (delta 0), pack-reused 1654
# Receiving objects: 100% (1654/1654), 34.83 MiB | 37.50 MiB/s, done.
# Resolving deltas: 100% (148/148), done.

# %%
# %cd   # to reset to the root path
# Out:
# [Errno 2] No such file or directory: '# to reset to the root path'
# /root/Neuro_Science

# %%
# !ls
# Out:
# Data.npy		Neuro_PCA.ipynb
# DataSet_with_Label.npz	README.md
# Dog-Cat-Classifier	Techniques_with_Bias_and_Variance.ipynb
# IF_data.npz

# %%
# %ls
# Out:
# Data.npy                Neuro_PCA.ipynb
# DataSet_with_Label.npz  README.md
# Dog-Cat-Classifier/     Techniques_with_Bias_and_Variance.ipynb
# IF_data.npz

# %%
# %cd Dog-Cat-Classifier 
# %ls
# Out:
# /root/Neuro_Science/Dog-Cat-Classifier
# Data/           LICENSE     README.md         test_dog.jpg
# get_dataset.py  Model.png   requirements.txt  train.py
# get_model.py    predict.py  test_cat.jpg

# %%
# %cd Data
# %ls
# Out:
# /root/Neuro_Science/Dog-Cat-Classifier/Data
# Checkpoints/  Layer_Outputs/  Model/  npy_train_data/  Train_Data/

# %%
# %cd Train_Data
# %ls
# Out:
# /root/Neuro_Science/Dog-Cat-Classifier/Data/Train_Data
# cat/  dog/

# %%
# %cd cat
# %ls
# Out:
# /root/Neuro_Science/Dog-Cat-Classifier/Data/Train_Data/cat
# cat.0.jpg*     cat.1126.jpg*  cat.172.jpg*  cat.299.jpg*  cat.424.jpg*
# cat.1000.jpg*  cat.1127.jpg*  cat.173.jpg*  cat.29.jpg*   cat.425.jpg*
# cat.1001.jpg*  cat.1128.jpg*  cat.174.jpg*  cat.2.jpg*    cat.426.jpg*
# cat.1002.jpg*  cat.1129.jpg*  cat.175.jpg*  cat.300.jpg*  cat.427.jpg*
# cat.1003.jpg*  cat.112.jpg*   cat.176.jpg*  cat.301.jpg*  cat.428.jpg*
# cat.1004.jpg*  cat.1130.jpg*  cat.177.jpg*  cat.302.jpg*  cat.429.jpg*
# cat.1005.jpg*  cat.1131.jpg*  cat.178.jpg*  cat.303.jpg*  cat.42.jpg*
# cat.1006.jpg*  cat.1132.jpg*  cat.179.jpg*  cat.304.jpg*  cat.430.jpg*
# cat.1007.jpg*  cat.1133.jpg*  cat.17.jpg*   cat.305.jpg*  cat.431.jpg*
# cat.1008.jpg*  cat.1134.jpg*  cat.180.jpg*  cat.306.jpg*  cat.432.jpg*
# cat.1009.jpg*  cat.1135.jpg*  cat.181.jpg*  cat.307.jpg*  cat.433.jpg*
# cat.100.jpg*   cat.1136.jpg*  cat.182.jpg*  cat.308.jpg*  cat.434.jpg*
# ...

# %%
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread('cat.1044.jpg')
plt.imshow(image)
