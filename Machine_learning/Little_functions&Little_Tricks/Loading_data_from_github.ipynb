# %% [markdown]
# <a href="https://colab.research.google.com/github/alifele/Machine_learning/blob/master/Machine_learning/Little_functions%26Little_Tricks/Loading_data_from_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Here is another way to upload data from github in colab by cloning github

# %% [markdown]
# # An example which was on web

# %%
# !pip install -q xlrd
# !git clone https://github.com/fastai/courses.git
# Out:
# Cloning into 'courses'...
# remote: Enumerating objects: 765, done.
# remote: Total 765 (delta 0), reused 0 (delta 0), pack-reused 765
# Receiving objects: 100% (765/765), 23.06 MiB | 28.28 MiB/s, done.
# Resolving deltas: 100% (407/407), done.

# %%
# !ls courses/deeplearning1/excel
# Out:
# collab_filter.xlsx  entropy_example.xlsx  layers_example.xlsx
# conv-example.xlsx   graddesc.xlsm

# %%
import pandas as pd
df = pd.read_excel('courses/deeplearning1/excel/layers_example.xlsx')
df
# Out:
#     Unnamed: 0                  x1        x2         x3  Unnamed: 4  \
# 0          NaN                   2  3.000000   1.000000         NaN
# 1          NaN                 NaN       NaN        NaN         NaN
# 2          NaN           weights 1       NaN        NaN         NaN
# 3          NaN             1.77752 -0.056013   0.222363   -0.125313
# 4          NaN             0.58263 -0.153056   0.122250    0.597437
# 5          NaN            0.385083  0.402703   0.107784   -1.325171
# 6          NaN                 NaN       NaN        NaN         NaN
# 7          NaN       activations 1       NaN        NaN         NaN
# 8          NaN             5.68802 -0.168491   0.919260    0.216514
# 9          NaN             5.68802  0.000000   0.919260    0.216514
# 10         NaN                 NaN       NaN        NaN         NaN
# 11         NaN           weights 2       NaN        NaN         NaN
# 12         NaN            -1.01076  0.470262   0.246334         NaN
# ...

# %% [markdown]
# # My example
# here is my code which I uploaded data from my repository

# %%
# !pip install -q xlrd
# !git clone https://github.com/alifele/Neuro_Science.git
# Out:
# fatal: destination path 'Neuro_Science' already exists and is not an empty directory.

# %%
# !ls Neuro_Science
# Out:
# Data.npy		Neuro_PCA.ipynb
# DataSet_with_Label.npz	README.md
# IF_data.npz		Techniques_with_Bias_and_Variance.ipynb

# %%
import numpy as np
data = np.load('Neuro_Science/DataSet_with_Label.npz')  # note that in address you should not write your github page name
